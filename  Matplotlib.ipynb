# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
xpoints=np.array([5,6])
ypoints=np.array([8,9])
plt.plot(xpoints,ypoints)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints=np.array([65,98])
ypoints=np.array([34,76])
plt.plot(xpoints,ypoints,"o")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints=np.array([65,98,34,27])
ypoints=np.array([34,76,98,56])
plt.plot(xpoints,ypoints)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints=np.array([65,98,34,27])
ypoints=np.array([34,76,98,56])
plt.plot(xpoints,ypoints,"*")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoints=np.array([34,76,98,56])
plt.plot(xpoints,ypoints,"*")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoints=np.array([34,76,98,56])
plt.plot(xpoints,ypoints)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints=np.array([65,98,34,27,67,45])
ypoints=np.array([34,76,98,56,98,20])
plt.plot(ypoints,marker ="*")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints=np.array([65,98,34,27,67,45])
ypoints=np.array([34,76,98,56,98,20])
plt.plot(xpoints,marker ="*")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
xpoints=np.array([65,98,34,27,67,45])
ypoints=np.array([34,76,98,56,98,20])
plt.plot(ypoints,marker ="*",linestyle ="dotted",c ="red")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#plot1
x = np.array([12,13,15,16])
y = np.array([45,47,48,38])
plt.subplot(1,2,1)
plt.plot(x,y)

#plot2
x =np.array([35,75,87,63])
y =np.array([65,98,46,36])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = np.array([12,13,15,16])
y = np.array([45,47,48,38])
plt.subplot(2,1,1)
plt.plot(x,y)
plt.plot(y,ls = "-",c = "pink")
#plot2
x =np.array([35,75,87,63])
y =np.array([65,98,46,36])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = np.array([86,98,35,67,87])
y = np.array([76,35,57,89,78])

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x = np.random.randint(100,size=(200))
y = np.random.randint(100,size=(200))
colors = np.random.randint(100,size=(200))
sizes = 20 * np.random.randint(100,size =(200))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()
